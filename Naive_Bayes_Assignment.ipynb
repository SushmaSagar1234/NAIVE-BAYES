# %% [markdown]
# # Importing Libararies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Dataset

# %%
dataset = pd.read_csv("/content/SalaryData_Train.csv")

# %%
dataset.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
dataset.education.unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' 7th-8th', ' Doctorate',
#        ' Assoc-voc', ' Prof-school', ' 5th-6th', ' 10th', ' Preschool',
#        ' 12th', ' 1st-4th'], dtype=object)

# %%
dataset.educationno.unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12,  4, 16, 11, 15,  3,  6,  1,  8,  2])

# %%
dataset.capitalgain.unique()
# Out:
# array([ 2174,     0, 14084,  5178,  5013,  2407, 14344, 15024,  7688,
#         4064,  4386,  7298,  1409,  3674,  1055,  2050,  2176,   594,
#        20051,  6849,  4101,  8614,  3411,  2597, 25236,  4650,  2463,
#         3103, 10605,  2964,  3325,  2580,  3471,  4865, 99999,  6514,
#         1471,  2329,  2105,  2885, 10520,  2202,  2961, 27828,  6767,
#         2228,  1506, 13550,  2635,  5556,  4787,  3781,  3137,  3818,
#          914,   401,  2829,  2977,  4934,  2062,  2354,  3464,  5455,
#        15020,  1424,  3273, 22040,  4416, 10566,  4931,  7430, 34095,
#         6497,  3908,   114,  2346,  2907,  1151,  9386,  2414,  2290,
#         3418, 15831, 41310,  4508,  2538,  3456,  1848,  3887,  7896,
#         5721,  9562,  6418,  1455,  2036,  3942,  1831, 11678,  2936,
#         2993,  7443,  6360,  4687,  1797,  6723,  2009,  3432,  6097,
#         1639,  2653, 18481, 25124,  7978,   991,  1173,  2387,  5060,
#         1086])

# %%
dataset.capitalloss.unique()
# Out:
# array([   0, 2042, 1408, 1902, 1887, 1719, 1762, 1564, 2179, 1816, 1980,
#        1977, 1876, 1340, 2206, 1741, 1485, 2339, 2415, 1380, 1721, 2051,
#        2377, 1669, 2352, 1672,  653, 2392, 1504, 1590, 1651, 1628, 1848,
#        2001, 1740, 2002, 1579, 2258, 1602, 2547, 2205, 1726, 2444, 1138,
#        2238,  625,  213, 1539,  880, 1668, 1092, 1594, 2231, 1844,  810,
#        2824, 2559, 2057, 1573, 1974,  974, 2174, 2149, 1735, 1258, 2603,
#        2282,  323, 2246, 1617, 1648, 1825, 3770, 1755, 3683, 2129, 4356,
#        2267, 2080, 2457,  419,  155, 3900, 2201, 1944, 2467, 2754, 2472,
#        3004, 1411])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
dataset.shape
# Out:
# (30161, 14)

# %%
dataset.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
dataset.Salary.unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
dataset = dataset.replace(to_replace = " <=50K",value = 1)

# %%
dataset = dataset.replace(to_replace = " >50K",value = 2)

# %%
dataset
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %% [markdown]
# #dropping unnecessary features

# %%
data = dataset.drop(columns = ['education', 'maritalstatus','relationship','race','sex','native'])

# %%
data
# Out:
#        age          workclass  educationno          occupation  capitalgain  \
# 0       39          State-gov           13        Adm-clerical         2174
# 1       50   Self-emp-not-inc           13     Exec-managerial            0
# 2       38            Private            9   Handlers-cleaners            0
# 3       53            Private            7   Handlers-cleaners            0
# 4       28            Private           13      Prof-specialty            0
# ...    ...                ...          ...                 ...          ...
# 30156   27            Private           12        Tech-support            0
# 30157   40            Private            9   Machine-op-inspct            0
# 30158   58            Private            9        Adm-clerical            0
# 30159   22            Private            9        Adm-clerical            0
# 30160   52       Self-emp-inc            9     Exec-managerial        15024
#
#        capitalloss  hoursperweek  Salary
# ...

# %% [markdown]
# #ENCODING THE CATEGORICAL DATA

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['workclass']= label_encoder.fit_transform(data['workclass'])

# %%
data['workclass'].unique()
# Out:
# array([5, 4, 2, 0, 1, 3, 6])

# %%
data['occupation']= label_encoder.fit_transform(data['occupation'])
data['occupation'].unique()
# Out:
# array([ 0,  3,  5,  9,  7, 11, 13,  4,  6, 12,  2, 10,  1,  8])

# %% [markdown]
# # Independent and dependent Variables

# %%
X = data.iloc[:, 0:7].values #X train values
y = data.iloc[:, 7].values # y train values

# %%
X
# Out:
# array([[   39,     5,    13, ...,  2174,     0,    40],
#        [   50,     4,    13, ...,     0,     0,    13],
#        [   38,     2,     9, ...,     0,     0,    40],
#        ...,
#        [   58,     2,     9, ...,     0,     0,    40],
#        [   22,     2,     9, ...,     0,     0,    20],
#        [   52,     3,     9, ..., 15024,     0,    40]])

# %%
y
# Out:
# array([1, 1, 1, ..., 1, 1, 2])

# %% [markdown]
# #TEST DATASET

# %%
test = pd.read_csv("/content/SalaryData_Test.csv")

# %%
test.shape
# Out:
# (15060, 14)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
test1 = test.drop_duplicates()

# %%
test1.shape
# Out:
# (14130, 14)

# %%
test2 = test1.dropna()

# %%
test2
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
test3 = test2.drop(columns = ['education', 'maritalstatus','relationship','race','sex','native'])

# %%
test3
# Out:
#        age      workclass  educationno          occupation  capitalgain  \
# 0       25        Private            7   Machine-op-inspct            0
# 1       38        Private            9     Farming-fishing            0
# 2       28      Local-gov           12     Protective-serv            0
# 3       44        Private           10   Machine-op-inspct         7688
# 4       34        Private            6       Other-service            0
# ...    ...            ...          ...                 ...          ...
# 15055   33        Private           13      Prof-specialty            0
# 15056   39        Private           13      Prof-specialty            0
# 15057   38        Private           13      Prof-specialty            0
# 15058   44        Private           13        Adm-clerical         5455
# 15059   35   Self-emp-inc           13     Exec-managerial            0
#
#        capitalloss  hoursperweek  Salary
# 0                0            40   <=50K
# ...

# %%
test3 = test3.replace(to_replace = " <=50K",value = 1)

# %%
test3 = test3.replace(to_replace = " >50K",value = 2)

# %%
test3
# Out:
#        age      workclass  educationno          occupation  capitalgain  \
# 0       25        Private            7   Machine-op-inspct            0
# 1       38        Private            9     Farming-fishing            0
# 2       28      Local-gov           12     Protective-serv            0
# 3       44        Private           10   Machine-op-inspct         7688
# 4       34        Private            6       Other-service            0
# ...    ...            ...          ...                 ...          ...
# 15055   33        Private           13      Prof-specialty            0
# 15056   39        Private           13      Prof-specialty            0
# 15057   38        Private           13      Prof-specialty            0
# 15058   44        Private           13        Adm-clerical         5455
# 15059   35   Self-emp-inc           13     Exec-managerial            0
#
#        capitalloss  hoursperweek  Salary
# 0                0            40       1
# ...

# %%
label_encoder_test = preprocessing.LabelEncoder()
test3['workclass']= label_encoder_test.fit_transform(test3['workclass'])
test3['occupation']= label_encoder_test.fit_transform(test3['occupation'])

# %%
test3
# Out:
#        age  workclass  educationno  occupation  capitalgain  capitalloss  \
# 0       25          2            7           6            0            0
# 1       38          2            9           4            0            0
# 2       28          1           12          10            0            0
# 3       44          2           10           6         7688            0
# 4       34          2            6           7            0            0
# ...    ...        ...          ...         ...          ...          ...
# 15055   33          2           13           9            0            0
# 15056   39          2           13           9            0            0
# 15057   38          2           13           9            0            0
# 15058   44          2           13           0         5455            0
# 15059   35          3           13           3            0            0
#
#        hoursperweek  Salary
# 0                40       1
# 1                50       1
# ...

# %%
X_test =  test3.iloc[:, 0:7].values

# %%
X_test
# Out:
# array([[  25,    2,    7, ...,    0,    0,   40],
#        [  38,    2,    9, ...,    0,    0,   50],
#        [  28,    1,   12, ...,    0,    0,   40],
#        ...,
#        [  38,    2,   13, ...,    0,    0,   50],
#        [  44,    2,   13, ..., 5455,    0,   40],
#        [  35,    3,   13, ...,    0,    0,   60]])

# %%
y_test = test3.iloc[:,7].values

# %%
y_test
# Out:
# array([1, 1, 2, ..., 1, 1, 2])

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X)
X_test = sc_X.fit_transform(X_test)

# %%
X_train
# Out:
# array([[ 0.04277892,  2.93594688,  1.12889813, ...,  0.14608503,
#         -0.21850808, -0.07773541],
#        [ 0.88026081,  1.88764517,  1.12889813, ..., -0.14744712,
#         -0.21850808, -2.33149486],
#        [-0.0333558 , -0.20895825, -0.4397325 , ..., -0.14744712,
#         -0.21850808, -0.07773541],
#        ...,
#        [ 1.48933854, -0.20895825, -0.4397325 , ..., -0.14744712,
#         -0.21850808, -0.07773541],
#        [-1.25151126, -0.20895825, -0.4397325 , ..., -0.14744712,
#         -0.21850808, -1.74718685],
#        [ 1.03253024,  0.83934346, -0.4397325 , ...,  1.88108414,
#         -0.21850808, -0.07773541]])

# %%
X_test
# Out:
# array([[-1.05408752, -0.22877429, -1.19914608, ..., -0.15005852,
#         -0.22610763, -0.08753833],
#        [-0.08603828, -0.22877429, -0.43064399, ..., -0.15005852,
#         -0.22610763,  0.72761694],
#        [-0.83069154, -1.23706521,  0.72210915, ..., -0.15005852,
#         -0.22610763, -0.08753833],
#        ...,
#        [-0.08603828, -0.22877429,  1.10636019, ..., -0.15005852,
#         -0.22610763,  0.72761694],
#        [ 0.36075367, -0.22877429,  1.10636019, ...,  0.54019335,
#         -0.22610763, -0.08753833],
#        [-0.30943426,  0.77951663,  1.10636019, ..., -0.15005852,
#         -0.22610763,  1.54277221]])

# %% [markdown]
# #ML Algorithm

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train,y)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 2, 1])

# %%
y_test
# Out:
# array([1, 1, 2, ..., 1, 1, 2])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(y_test,y_pred)
acc = accuracy_score(y_test,y_pred)
print(cm)
print(acc)
# Out:
# [[10040   580]
#  [ 2406  1104]]
# 0.7886765746638358

# %% [markdown]
# #DATA Visualization
